# %%
import numpy as np
import os
#from scipy.misc.pilutil import imread, imresize
import imageio.v2 as imageio
from imageio import imread
import datetime
from skimage.transform import resize

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
#tf.set_random_seed(30)
tf.random.set_seed(30)

# %%
train_doc = np.random.permutation(open('C:\\Users\\JITHAN\\Downloads\\Project_data\\train.csv').readlines())
val_doc = np.random.permutation(open('C:\\Users\\JITHAN\\Downloads\\Project_data\\val.csv').readlines())
batch_size = 16

# %%
train_path="C:\\Users\\JITHAN\\Downloads\\Project_data\\train"
val_path="C:\\Users\\JITHAN\\Downloads\\Project_data\\val"

# %%
resize_val = 128

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    #img_idx = [0,3,7,8,10] #create a list of image numbers you want to use for a particular video
    img_idx = range(0,30,2)
    
    ## Complete Batches
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,30,resize_val,resize_val,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image_resized=resize(image,(resize_val,resize_val,3))
                    
                    batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        last_batch_size = len(t)%batch_size
        if last_batch_size:
            batch_data = np.zeros((batch_size,30,resize_val,resize_val,3))
            batch_labels = np.zeros((batch_size,5))
            for folder in range(last_batch_size):
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    image_resized=resize(image,(resize_val,resize_val,3))
                    
                    batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

# %%
train_gen = generator(train_path,train_doc,30)

# %%
curr_dt_time = datetime.datetime.now()
train_path="C:\\Users\\JITHAN\\Downloads\\Project_data\\train"
val_path="C:\\Users\\JITHAN\\Downloads\\Project_data\\val"
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 20# choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %%
cnn_model = Sequential()
cnn_model.add(Conv3D(16, (3, 3, 3), padding='same',
         input_shape=(30,resize_val,resize_val,3)))
cnn_model.add(Activation('relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling3D(pool_size=(2, 2, 2)))

cnn_model.add(Conv3D(32, (2, 2, 2), padding='same'))
cnn_model.add(Activation('relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling3D(pool_size=(2, 2, 2)))

cnn_model.add(Conv3D(64, (2, 2, 2), padding='same'))
cnn_model.add(Activation('relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling3D(pool_size=(2, 2, 2)))

cnn_model.add(Conv3D(128, (2, 2, 2), padding='same'))
cnn_model.add(Activation('relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling3D(pool_size=(2, 2, 2)))

cnn_model.add(Flatten())
cnn_model.add(Dense(128,activation='relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(0.5))

cnn_model.add(Dense(64,activation='relu'))
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(0.25))


cnn_model.add(Dense(5,activation='softmax'))

#optimiser = optimizers.Adam()
#optimiser = 'sgd'
cnn_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 30, 128, 128, 16)  1312
#
#  activation (Activation)     (None, 30, 128, 128, 16)  0
#
#  batch_normalization (BatchN  (None, 30, 128, 128, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 15, 64, 64, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 64, 64, 32)    4128
#
#  activation_1 (Activation)   (None, 15, 64, 64, 32)    0
#
#  batch_normalization_1 (Batc  (None, 15, 64, 64, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 32, 32, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 32, 32, 64)     16448
#
#  activation_2 (Activation)   (None, 7, 32, 32, 64)     0
#
#  batch_normalization_2 (Batc  (None, 7, 32, 32, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 16, 16, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 3, 16, 16, 128)    65664
#
#  activation_3 (Activation)   (None, 3, 16, 16, 128)    0
#
#  batch_normalization_3 (Batc  (None, 3, 16, 16, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 8, 8, 128)     0
#  3D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 1,146,565
# Trainable params: 1,145,701
# Non-trainable params: 864
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=5)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %%
num_epochs=50
steps_per_epoch=int(num_train_sequences/batch_size)
cnn_model_history= cnn_model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                                 callbacks=callbacks_list, validation_data=val_generator, 
                                 validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  C:\Users\JITHAN\Downloads\Project_data\train ; batch size = 16
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/50
# 40/41 [============================>.] - ETA: 9s - loss: 1.7744 - categorical_accuracy: 0.3641
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:38: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 41/41 [==============================] - ETA: 0s - loss: 1.7699 - categorical_accuracy: 0.3628Source path =  C:\Users\JITHAN\Downloads\Project_data\val ; batch size = 16
# 41/41 [==============================] - 434s 11s/step - loss: 1.7699 - categorical_accuracy: 0.3628 - val_loss: 33.0286 - val_categorical_accuracy: 0.2679 - lr: 0.0100
# Epoch 2/50
# 41/41 [==============================] - 440s 11s/step - loss: 1.4766 - categorical_accuracy: 0.4162 - val_loss: 12.5073 - val_categorical_accuracy: 0.1786 - lr: 0.0100
# Epoch 3/50
# 41/41 [==============================] - 438s 11s/step - loss: 1.2649 - categorical_accuracy: 0.4832 - val_loss: 6.5760 - val_categorical_accuracy: 0.2143 - lr: 0.0100
# Epoch 4/50
# 41/41 [==============================] - 440s 11s/step - loss: 1.1666 - categorical_accuracy: 0.5396 - val_loss: 4.0469 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 5/50
# 41/41 [==============================] - ETA: 0s - loss: 1.0647 - categorical_accuracy: 0.5716
# Epoch 5: val_loss improved from inf to 1.59904, saving model to model_init_2022-07-1117_51_46.079847\model-00005-1.06473-0.57165-1.59904-0.33036.h5
# 41/41 [==============================] - 440s 11s/step - loss: 1.0647 - categorical_accuracy: 0.5716 - val_loss: 1.5990 - val_categorical_accuracy: 0.3304 - lr: 0.0100
# Epoch 6/50
# 41/41 [==============================] - 453s 11s/step - loss: 1.0116 - categorical_accuracy: 0.5808 - val_loss: 1.2894 - val_categorical_accuracy: 0.3839 - lr: 0.0100
# Epoch 7/50
# 41/41 [==============================] - 437s 11s/step - loss: 0.9230 - categorical_accuracy: 0.6326 - val_loss: 0.9285 - val_categorical_accuracy: 0.5179 - lr: 0.0100
# Epoch 8/50
# 41/41 [==============================] - 438s 11s/step - loss: 0.8217 - categorical_accuracy: 0.6707 - val_loss: 1.2272 - val_categorical_accuracy: 0.4286 - lr: 0.0100
# Epoch 9/50
# 41/41 [==============================] - 440s 11s/step - loss: 0.7592 - categorical_accuracy: 0.6921 - val_loss: 1.3207 - val_categorical_accuracy: 0.3929 - lr: 0.0100
# Epoch 10/50
# 41/41 [==============================] - ETA: 0s - loss: 0.
50
# 41/41 [==============================] - ETA: 0s - loss: 0.3572 - categorical_accuracy: 0.8704
# Epoch 40: val_loss did not improve from 0.42983
# 41/41 [==============================] - 440s 11s/step - loss: 0.3572 - categorical_accuracy: 0.8704 - val_loss: 0.5032 - val_categorical_accuracy: 0.7857 - lr: 1.6000e-05
# Epoch 41/50
# 41/41 [==============================] - 436s 11s/step - loss: 0.3645 - categorical_accuracy: 0.8613 - val_loss: 0.5572 - val_categorical_accuracy: 0.7857 - lr: 1.6000e-05
# Epoch 42/50
# 41/41 [==============================] - 432s 11s/step - loss: 0.3273 - categorical_accuracy: 0.8857 - val_loss: 0.5315 - val_categorical_accuracy: 0.7857 - lr: 1.6000e-05
# Epoch 43/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3736 - categorical_accuracy: 0.8674
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.199999628122896e-06.
# 41/41 [==============================] - 433s 11s/step - loss: 0.3736 - categorical_accuracy: 0.8674 - val_loss: 0.5200 - val_categorical_accuracy: 0.7946 - lr: 1.6000e-05
# Epoch 44/50
# 41/41 [==============================] - 431s 11s/step - loss: 0.3364 - categorical_accuracy: 0.8948 - val_loss: 0.5054 - val_categorical_accuracy: 0.8036 - lr: 3.2000e-06
# Epoch 45/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3264 - categorical_accuracy: 0.8811
# Epoch 45: val_loss did not improve from 0.42983
# 41/41 [==============================] - 431s 11s/step - loss: 0.3264 - categorical_accuracy: 0.8811 - val_loss: 0.4623 - val_categorical_accuracy: 0.8036 - lr: 3.2000e-06
# Epoch 46/50
# 41/41 [==============================] - 432s 11s/step - loss: 0.3666 - categorical_accuracy: 0.8643 - val_loss: 0.4832 - val_categorical_accuracy: 0.8214 - lr: 3.2000e-06
# Epoch 47/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3299 - categorical_accuracy: 0.8720
# Epoch 47: ReduceLROnPlateau reducing learning rate to 6.399999165296323e-07.
# 41/41 [==============================] - 431s 11s/step - loss: 0.3299 - categorical_accuracy: 0.8720 - val_loss: 0.6205 - val_categorical_accuracy: 0.7500 - lr: 3.2000e-06
# Epoch 48/50
# 41/41 [==============================] - 430s 11s/step - loss: 0.3547 - categorical_accuracy: 0.8674 - val_loss: 0.4473 - val_categorical_accuracy: 0.8304 - lr: 6.4000e-07
# Epoch 49/50
# 41/41 [==============================] - 411s 10s/step - loss: 0.3284 - categorical_accuracy: 0.8811 - val_loss: 0.5081 - val_categorical_accuracy: 0.8036 - lr: 6.4000e-07
# Epoch 50/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3206 - categorical_accuracy: 0.8902
# Epoch 50: val_loss did not improve from 0.42983
# 41/41 [==============================] - 411s 10s/step - loss: 0.3206 - categorical_accuracy: 0.8902 - val_loss: 0.5184 - val_categorical_accuracy: 0.7857 - lr: 6.4000e-07

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
axes[0].plot(cnn_model_history.history['loss'])   
axes[0].plot(cnn_model_history.history['val_loss'])
axes[0].legend(['loss','val_loss'])

axes[1].plot(cnn_model_history.history['categorical_accuracy'])   
axes[1].plot(cnn_model_history.history['val_categorical_accuracy'])
axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D

# %%
gru_model = Sequential()

gru_model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                          input_shape=(30,resize_val,resize_val,3)))
gru_model.add(TimeDistributed(BatchNormalization()))
gru_model.add(TimeDistributed(MaxPooling2D((2, 2))))

gru_model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
gru_model.add(TimeDistributed(BatchNormalization()))
gru_model.add(TimeDistributed(MaxPooling2D((2, 2))))

gru_model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
gru_model.add(TimeDistributed(BatchNormalization()))
gru_model.add(TimeDistributed(MaxPooling2D((2, 2))))

gru_model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
gru_model.add(TimeDistributed(BatchNormalization()))
gru_model.add(TimeDistributed(MaxPooling2D((2, 2))))


gru_model.add(TimeDistributed(Flatten()))


gru_model.add(GRU(128))
gru_model.add(Dropout(0.5))

gru_model.add(Dense(64,activation='relu'))
gru_model.add(Dropout(0.25))

gru_model.add(Dense(5, activation='softmax'))
gru_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 128, 128, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 128, 128, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 64, 64, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 64, 64, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 64, 64, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 32, 32, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 32, 32, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 32, 32, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 30, 16, 16, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 30, 16, 16, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 30, 16, 16, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 30, 8, 8, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 30, 8192)         0
#  stributed)
#
#  gru (GRU)                   (None, 128)               3195648
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3,302,629
# Trainable params: 3,302,149
# Non-trainable params: 480
# _________________________________________________________________

# %%
num_epochs=50
steps_per_epoch=int(num_train_sequences/batch_size)
gru_model_history = gru_model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                                  callbacks=callbacks_list, validation_data=val_generator, 
                                  validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/50
#  5/41 [==>...........................] - ETA: 2:33 - loss: 2.1162 - categorical_accuracy: 0.2125
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:38: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 41/41 [==============================] - 193s 5s/step - loss: 1.9299 - categorical_accuracy: 0.2241 - val_loss: 1.4350 - val_categorical_accuracy: 0.1875 - lr: 0.0100
# Epoch 2/50
# 41/41 [==============================] - 187s 5s/step - loss: 1.7424 - categorical_accuracy: 0.1997 - val_loss: 1.4391 - val_categorical_accuracy: 0.2232 - lr: 0.0100
# Epoch 3/50
# 41/41 [==============================] - 186s 5s/step - loss: 1.6780 - categorical_accuracy: 0.2302 - val_loss: 1.4475 - val_categorical_accuracy: 0.2143 - lr: 0.0100
# Epoch 4/50
# 41/41 [==============================] - 186s 5s/step - loss: 1
50
# 41/41 [==============================] - 187s 5s/step - loss: 1.2040 - categorical_accuracy: 0.5076 - val_loss: 1.0228 - val_categorical_accuracy: 0.5268 - lr: 4.0000e-04
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 1.1560 - categorical_accuracy: 0.5122
# Epoch 40: val_loss did not improve from 0.42983
# 41/41 [==============================] - 188s 5s/step - loss: 1.1560 - categorical_accuracy: 0.5122 - val_loss: 0.9706 - val_categorical_accuracy: 0.5536 - lr: 4.0000e-04
# Epoch 41/50
# 41/41 [==============================] - 186s 5s/step - loss: 1.1358 - categorical_accuracy: 0.5412 - val_loss: 0.9320 - val_categorical_accuracy: 0.6161 - lr: 4.0000e-04
# Epoch 42/50
# 41/41 [==============================] - 189s 5s/step - loss: 1.1665 - categorical_accuracy: 0.4954 - val_loss: 0.9838 - val_categorical_accuracy: 0.5536 - lr: 4.0000e-04
# Epoch 43/50
# 41/41 [==============================] - 188s 5s/step - loss: 1.1340 - categorical_accuracy: 0.5183 - val_loss: 0.9172 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04
# Epoch 44/50
# 41/41 [==============================] - 185s 5s/step - loss: 1.1097 - categorical_accuracy: 0.5366 - val_loss: 0.8912 - val_categorical_accuracy: 0.5804 - lr: 4.0000e-04
# Epoch 45/50
# 41/41 [==============================] - ETA: 0s - loss: 1.1679 - categorical_accuracy: 0.5000
# Epoch 45: val_loss did not improve from 0.42983
# 41/41 [==============================] - 188s 5s/step - loss: 1.1679 - categorical_accuracy: 0.5000 - val_loss: 1.0197 - val_categorical_accuracy: 0.5982 - lr: 4.0000e-04
# Epoch 46/50
# 41/41 [==============================] - 188s 5s/step - loss: 1.1080 - categorical_accuracy: 0.5320 - val_loss: 0.9690 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-04
# Epoch 47/50
# 41/41 [==============================] - 187s 5s/step - loss: 1.1263 - categorical_accuracy: 0.5152 - val_loss: 0.8794 - val_categorical_accuracy: 0.6429 - lr: 4.0000e-04
# Epoch 48/50
# 41/41 [==============================] - 186s 5s/step - loss: 1.0858 - categorical_accuracy: 0.5686 - val_loss: 0.9293 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04
# Epoch 49/50
# 41/41 [==============================] - 188s 5s/step - loss: 1.0862 - categorical_accuracy: 0.5579 - val_loss: 0.8878 - val_categorical_accuracy: 0.6161 - lr: 4.0000e-04
# Epoch 50/50
# 41/41 [==============================] - ETA: 0s - loss: 1.0833 - categorical_accuracy: 0.5503
# Epoch 50: val_loss did not improve from 0.42983
# 41/41 [==============================] - 186s 5s/step - loss: 1.0833 - categorical_accuracy: 0.5503 - val_loss: 0.8834 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
axes[0].plot(gru_model_history.history['loss'])   
axes[0].plot(gru_model_history.history['val_loss'])
axes[0].legend(['loss','val_loss'])

axes[1].plot(gru_model_history.history['categorical_accuracy'])   
axes[1].plot(gru_model_history.history['val_categorical_accuracy'])
axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
lstm_model = Sequential()

lstm_model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                          input_shape=(30,resize_val,resize_val,3)))
lstm_model.add(TimeDistributed(BatchNormalization()))
lstm_model.add(TimeDistributed(MaxPooling2D((2, 2))))

lstm_model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
lstm_model.add(TimeDistributed(BatchNormalization()))
lstm_model.add(TimeDistributed(MaxPooling2D((2, 2))))

lstm_model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
lstm_model.add(TimeDistributed(BatchNormalization()))
lstm_model.add(TimeDistributed(MaxPooling2D((2, 2))))

lstm_model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
lstm_model.add(TimeDistributed(BatchNormalization()))
lstm_model.add(TimeDistributed(MaxPooling2D((2, 2))))


lstm_model.add(TimeDistributed(Flatten()))


lstm_model.add(LSTM(units=128))
lstm_model.add(Dropout(0.25))

lstm_model.add(Dense(64,activation='relu'))
lstm_model.add(Dropout(0.25))

lstm_model.add(Dense(5, activation='softmax'))
lstm_model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
lstm_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_13 (TimeDi  (None, 30, 128, 128, 16)  448
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 30, 128, 128, 16)  64
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 30, 64, 64, 16)   0
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 30, 64, 64, 32)   4640
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 30, 64, 64, 32)   128
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 30, 32, 32, 32)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 30, 32, 32, 64)   18496
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 30, 32, 32, 64)   256
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 30, 16, 16, 64)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 30, 16, 16, 128)  73856
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 30, 16, 16, 128)  512
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 30, 8, 8, 128)    0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 30, 8192)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               4260352
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4,367,333
# Trainable params: 4,366,853
# Non-trainable params: 480
# _________________________________________________________________

# %%
num_epochs=50
steps_per_epoch=int(num_train_sequences/batch_size)
lstm_model_history = lstm_model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                                    callbacks=callbacks_list, validation_data=val_generator, 
                                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/50
# 12/41 [=======>......................] - ETA: 2:02 - loss: 1.7210 - categorical_accuracy: 0.1667
# C:\Users\JITHAN\AppData\Local\Temp/ipykernel_33836/3915130081.py:38: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
50
# 41/41 [==============================] - 191s 5s/step - loss: 1.3079 - categorical_accuracy: 0.4284 - val_loss: 1.1908 - val_categorical_accuracy: 0.4643 - lr: 0.0020
# Epoch 17/50
# 41/41 [==============================] - 191s 5s/step - loss: 1.2207 - categorical_accuracy: 0.5046 - val_loss: 1.1713 - val_categorical_accuracy: 0.4107 - lr: 0.0020
# Epoch 18/50
# 41/41 [==============================] - 192s 5s/step - loss: 1.2067 - categorical_accuracy: 0.5137 - val_loss: 1.1794 - val_categorical_accuracy: 0.4375 - lr: 0.0020
# Epoch 19/50
# 41/41 [==============================] - 190s 5s/step - loss: 1.1901 - categorical_accuracy: 0.5061 - val_loss: 1.1729 - val_categorical_accuracy: 0.4554 - lr: 0.0020
# Epoch 20/50
# 41/41 [==============================] - ETA: 0s - loss: 1.1287 - categorical_accuracy: 0.5381
# Epoch 20: val_loss did not improve from 0.42983
# 41/41 [==============================] - 190s 5s/step - loss: 1.1287 - categorical_accuracy: 0.5381 - val_loss: 1.1447 - val_categorical_accuracy: 0.4821 - lr: 0.0020
# Epoch 21/50
# 41/41 [==============================] - 191s 5s/step - loss: 1.1013 - categorical_accuracy: 0.5777 - val_loss: 1.0191 - val_categorical_accuracy: 0.5000 - lr: 0.0020
# Epoch 22/50
# 41/41 [==============================] - 190s 5s/step - loss: 1.0964 - categorical_accuracy: 0.5655 - val_loss: 1.1158 - val_categorical_accuracy: 0.4286 - lr: 0.0020
# Epoch 23/50
# 41/41 [==============================] - 191s 5s/step - loss: 1.0482 - categorical_accuracy: 0.6082 - val_loss: 0.9978 - val_categorical_accuracy: 0.5446 - lr: 0.0020
# Epoch 24/50
# 41/41 [==============================] - 191s 5s/step - loss: 1.0761 - categorical_accuracy: 0.5351 - val_loss: 1.1318 - val_categorical_accuracy: 0.4554 - lr: 0.0020
# Epoch 25/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9482 - categorical_accuracy: 0.6479
# Epoch 25: val_loss did not improve from 0.42983
# 41/41 [==============================] - 190s 5s/step - loss: 0.9482 - categorical_accuracy: 0.6479 - val_loss: 1.1352 - val_categorical_accuracy: 0.4196 - lr: 0.0020
# Epoch 26/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.9984 - categorical_accuracy: 0.6448 - val_loss: 1.0537 - val_categorical_accuracy: 0.5000 - lr: 0.0020
# Epoch 27/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9398 - categorical_accuracy: 0.6570
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 41/41 [==============================] - 192s 5s/step - loss: 0.9398 - categorical_accuracy: 0.6570 - val_loss: 1.2747 - val_categorical_accuracy: 0.3393 - lr: 0.0020
# Epoch 28/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.8588 - categorical_accuracy: 0.7012 - val_loss: 1.0218 - val_categorical_accuracy: 0.5804 - lr: 4.0000e-04
# Epoch 29/50
# 41/41 [==============================] - 192s 5s/step - loss: 0.8271 - categorical_accuracy: 0.7409 - val_loss: 0.8882 - val_categorical_accuracy: 0.6161 - lr: 4.0000e-04
# Epoch 30/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7998 - categorical_accuracy: 0.7454
# Epoch 30: val_loss did not improve from 0.42983
# 41/41 [==============================] - 192s 5s/step - loss: 0.7998 - categorical_accuracy: 0.7454 - val_loss: 0.7770 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04
# Epoch 31/50
# 41/41 [==============================] - 192s 5s/step - loss: 0.7868 - categorical_accuracy: 0.7576 - val_loss: 0.8388 - val_categorical_accuracy: 0.5804 - lr: 4.0000e-04
# Epoch 32/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.7769 - categorical_accuracy: 0.7744 - val_loss: 0.7627 - val_categorical_accuracy: 0.6607 - lr: 4.0000e-04
# Epoch 33/50
# 41/41 [==============================] - 190s 5s/step - loss: 0.7855 - categorical_accuracy: 0.7439 - val_loss: 0.8075 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-04
# Epoch 34/50
# 41/41 [==============================] - 190s 5s/step - loss: 0.7478 - categorical_accuracy: 0.7866 - val_loss: 0.8134 - val_categorical_accuracy: 0.5804 - lr: 4.0000e-04
# Epoch 35/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7469 - categorical_accuracy: 0.7820
# Epoch 35: val_loss did not improve from 0.42983
# 41/41 [==============================] - 192s 5s/step - loss: 0.7469 - categorical_accuracy: 0.7820 - val_loss: 0.7571 - val_categorical_accuracy: 0.5982 - lr: 4.0000e-04
# Epoch 36/50
# 41/41 [==============================] - 193s 5s/step - loss: 0.7241 - categorical_accuracy: 0.7851 - val_loss: 0.8044 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04
# Epoch 37/50
# 41/41 [==============================] - 200s 5s/step - loss: 0.7173 - categorical_accuracy: 0.7622 - val_loss: 0.7590 - val_categorical_accuracy: 0.6071 - lr: 4.0000e-04
# Epoch 38/50
# 41/41 [==============================] - 193s 5s/step - loss: 0.7129 - categorical_accuracy: 0.7866 - val_loss: 0.7650 - val_categorical_accuracy: 0.6161 - lr: 4.0000e-04
# Epoch 39/50
# 41/41 [==============================] - 193s 5s/step - loss: 0.6771 - categorical_accuracy: 0.7988 - val_loss: 0.7541 - val_categorical_accuracy: 0.6429 - lr: 4.0000e-04
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6787 - categorical_accuracy: 0.8064
# Epoch 40: val_loss did not improve from 0.42983
# 41/41 [==============================] - 189s 5s/step - loss: 0.6787 - categorical_accuracy: 0.8064 - val_loss: 0.7769 - val_categorical_accuracy: 0.6339 - lr: 4.0000e-04
# Epoch 41/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.6675 - categorical_accuracy: 0.8171 - val_loss: 0.7280 - val_categorical_accuracy: 0.6696 - lr: 4.0000e-04
# Epoch 42/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.6845 - categorical_accuracy: 0.7866 - val_loss: 0.7243 - val_categorical_accuracy: 0.6607 - lr: 4.0000e-04
# Epoch 43/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.6655 - categorical_accuracy: 0.7912 - val_loss: 0.7348 - val_categorical_accuracy: 0.6518 - lr: 4.0000e-04
# Epoch 44/50
# 41/41 [==============================] - 193s 5s/step - loss: 0.6564 - categorical_accuracy: 0.8140 - val_loss: 0.7009 - val_categorical_accuracy: 0.6429 - lr: 4.0000e-04
# Epoch 45/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6426 - categorical_accuracy: 0.8110
# Epoch 45: val_loss did not improve from 0.42983
# 41/41 [==============================] - 191s 5s/step - loss: 0.6426 - categorical_accuracy: 0.8110 - val_loss: 0.8397 - val_categorical_accuracy: 0.5982 - lr: 4.0000e-04
# Epoch 46/50
# 41/41 [==============================] - 192s 5s/step - loss: 0.6547 - categorical_accuracy: 0.8079 - val_loss: 0.7156 - val_categorical_accuracy: 0.6339 - lr: 4.0000e-04
# Epoch 47/50
# 41/41 [==============================] - 189s 5s/step - loss: 0.5982 - categorical_accuracy: 0.8201 - val_loss: 0.7347 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-04
# Epoch 48/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5922 - categorical_accuracy: 0.8338
# Epoch 48: ReduceLROnPlateau reducing learning rate to 7.999999215826393e-05.
# 41/41 [==============================] - 192s 5s/step - loss: 0.5922 - categorical_accuracy: 0.8338 - val_loss: 0.7574 - val_categorical_accuracy: 0.6250 - lr: 4.0000e-04
# Epoch 49/50
# 41/41 [==============================] - 191s 5s/step - loss: 0.5518 - categorical_accuracy: 0.8506 - val_loss: 0.6900 - val_categorical_accuracy: 0.6607 - lr: 8.0000e-05
# Epoch 50/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5968 - categorical_accuracy: 0.8293
# Epoch 50: val_loss did not improve from 0.42983
# 41/41 [==============================] - 191s 5s/step - loss: 0.5968 - categorical_accuracy: 0.8293 - val_loss: 0.7775 - val_categorical_accuracy: 0.6250 - lr: 8.0000e-05

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
axes[0].plot(lstm_model_history.history['loss'])   
axes[0].plot(lstm_model_history.history['val_loss'])
axes[0].legend(['loss','val_loss'])

axes[1].plot(lstm_model_history.history['categorical_accuracy'])   
axes[1].plot(lstm_model_history.history['val_categorical_accuracy'])
axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      1.0.0
# alice-blue                   1.0.2
# anyio                        3.4.0
# argon2-cffi                  21.1.0
# asgiref                      3.4.1
# astunparse                   1.6.3
# attrs                        21.2.0
# Augmentor                    0.2.10
# Babel                        2.9.1
# backcall                     0.2.0
# beautifulsoup4               4.10.0
# bleach                       4.1.0
# bs4                          0.0.1
# cachetools                   5.2.0
# certifi                      2021.10.8
# cffi                         1.15.0
# charset-normalizer           2.0.8
# click                        8.0.3
# colorama                     0.4.4
# cycler                       0.11.0
# debugpy                      1.5.1
# decorator                    5.1.0
# defusedxml                   0.7.1
# Django                       4.0.1
# entrypoints                  0.3
# et-xmlfile                   1.1.0
# Flask                        2.0.2
# flatbuffers                  2.0
# fonttools                    4.28.3
# future                       0.18.2
# gast                         0.5.3
# google-auth                  2.6.6
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.46.3
# h5py                         3.7.0
# idna                         3.3
# imageio                      2.19.3
# ipykernel                    6.5.1
# ipython                      7.30.0
# ipython-genutils             0.2.0
# itsdangerous                 2.0.1
# jedi                         0.18.1
# Jinja2                       3.0.3
# joblib                       1.1.0
# json5                        0.9.6
# jsonschema                   4.2.1
# jupyter-client               7.1.0
# jupyter-core                 4.9.1
# jupyter-http-over-ws         0.0.8
# jupyter-server               1.12.1
# jupyterlab                   3.2.4
# jupyterlab-pygments          0.1.2
# jupyterlab-server            2.8.2
# keras                        2.8.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.3.2
# libclang                     14.0.1
# Markdown                     3.3.7
# MarkupSafe                   2.0.1
# matplotlib                   3.5.1
# matplotlib-inline            0.1.3
# mistune                      0.8.4
# nbclassic                    0.3.4
# nbclient                     0.5.9
# nbconvert                    6.3.0
# nbformat                     5.1.3
# nest-asyncio                 1.5.1
# networkx                     2.8.4
# notebook                     6.4.6
# numpy                        1.21.4
# oauthlib                     3.2.0
# opencv-python                4.6.0.66
# openpyxl                     3.0.10
# opt-einsum                   3.3.0
# packaging                    21.3
# pandas                       1.3.4
# pandocfilters                1.5.0
# parso                        0.8.2
# patsy                        0.5.2
# pickleshare                  0.7.5
# Pillow                       8.4.0
# pip                          21.2.3
# playsound                    1.3.0
# plotly                       5.4.0
# prometheus-client            0.12.0
# prompt-toolkit               3.0.23
# protlib                      1.4
# protobuf                     3.19.4
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycparser                    2.21
# Pygments                     2.10.0
# pymongo                      4.0.2
# pyparsing                    3.0.6
# pyrsistent                   0.18.0
# python-dateutil              2.8.2
# pytz                         2021.3
# PyWavelets                   1.3.0
# pywin32                      302
# pywinpty                     1.1.6
# pyzmq                        22.3.0
# requests                     2.26.0
# requests-oauthlib            1.3.1
# rsa                          4.8
# scikit-image                 0.19.3
# scikit-learn                 1.0.2
# scipy                        1.8.1
# seaborn                      0.11.2
# Send2Trash                   1.8.0
# setuptools                   57.4.0
# six                          1.16.0
# sklearn                      0.0
# smartapi-python              1.2.9
# sniffio                      1.2.0
# soupsieve                    2.3.1
# sqlparse                     0.4.2
# statsmodels                  0.13.1
# tenacity                     8.0.1
# tensorboard                  2.8.0
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.8.0
# tensorflow-io-gcs-filesystem 0.26.0
# termcolor                    1.1.0
# terminado                    0.12.1
# testpath                     0.5.0
# tf-estimator-nightly         2.8.0.dev2021122109
# threadpoolctl                3.1.0
# tifffile                     2022.5.4
# tornado                      6.1
# tqdm                         4.64.0
# traitlets                    5.1.1
# typing_extensions            4.2.0
# tzdata                       2021.5
# urllib3                      1.26.7
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             1.2.1
# Werkzeug                     2.0.2
# wheel                        0.37.1
# wrapt                        1.14.1
# xgboost                      1.6.0
# xlwings                      0.25.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\python\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Python\python.exe -m pip install --upgrade pip' command.
